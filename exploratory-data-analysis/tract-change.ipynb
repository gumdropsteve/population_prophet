# %%
import csv
import xlrd
import pandas as pd

# https://www.census.gov/content/census/en/data/tables/time-series/dec/metro-micro/tract-change-00-10.html
tract_change = pd.read_excel( '../data/tract-change/2010/censustract-00-10.xlsx' )
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-1-85e153a074c3> in <module>
#       4
#       5 # https://www.census.gov/content/census/en/data/tables/time-series/dec/metro-micro/tract-change-00-10.html
# ----> 6 tract_change = pd.read_excel( '../data/tract-change/2010/censustract-00-10.xlsx' )
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     186                 else:
#     187                     kwargs[new_arg_name] = new_arg_value
# --> 188             return func(*args, **kwargs)
#     189         return wrapper
#     190     return _deprecate_kwarg
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     186                 else:
# ...

# %%
# figure out what we have
tract_change.info() , tract_change.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 74002 entries, 0 to 74001
# Data columns (total 20 columns):
# GEOID      74002 non-null int64
# ST10       74002 non-null int64
# COU10      74002 non-null int64
# TRACT10    74002 non-null int64
# AREAL10    74002 non-null float64
# AREAW10    74002 non-null float64
# CSA09      46997 non-null float64
# CBSA09     68397 non-null float64
# CBSA_T     68397 non-null object
# MDIV09     19055 non-null float64
# CSI        74002 non-null int64
# COFLG      68397 non-null object
# POP00      74002 non-null int64
# HU00       74002 non-null int64
# POP10      74002 non-null int64
# HU10       74002 non-null int64
# NPCHG      74002 non-null int64
# PPCHG      74002 non-null object
# NHCHG      74002 non-null int64
# PHCHG      74002 non-null object
# dtypes: float64(5), int64(11), object(4)
# memory usage: 11.3+ MB
# (None,
#                GEOID          ST10         COU10        TRACT10       AREAL10  \
# ...

# %% [markdown]
# - notes:
#     - abbreviations, sick
# - actions:
#     - figure out what abbreviations mean

# %%
# following is from word doc
abbreviations_titles = [ 'Variable' , 'Variable Description' ]
# make csv
with open( '../data/tract-change/2010/tract-change-abbreviations.csv' , 'w' ) as csvfile:
    filewriter = csv.writer( csvfile , delimiter=',' )
    filewriter.writerow( abbreviations_titles )

abbreviations_explained = (['GEOID' , 'Concatenated State-County-Census Tract Code'], 
                           ['ST10' , 'State FIPS Code'], ['COU10' , 'County FIPS Code'], ['TRACT10' , 'Census Tract Code'], 
                           ['AREAL10', 'Land area (square miles)'], ['AREAW10' , 'Water area (square miles)'], 
                           ['CSA09' , 'Combined Statistical Area Code'], ['CBSA09' , 'Core Based Statistical Area (CBSA) Code'], 
                           ['CBSA_T' , 'Core Based Statistical Area Title'], ['MDIV09' , 'Metropolitan Division Code'], 
                           ['CSI' , 'CBSA Status Indicator (1=Metropolitan statistical area, 2=Micropolitan statistical area, 3=Outside CBSA)'], 
                           ['COFLG' , 'Central/Outlying County Flag (C=Central county, O=Outlying county)'], 
                           ['POP00' , 'Total population (2000)'], ['HU00' , 'Total housing units (2000)'], 
                           ['POP10' , 'Total population (2010)'], ['HU10' , 'Total housing units (2010)'], 
                           ['NPCHG' , 'Numeric population change: 2000 to 2010'], 
                           ['PPCHG' , 'Percent population change: 2000 to 2010'], 
                           ['NHCHG' , 'Numeric change in housing units: 2000 to 2010'], 
                           ['PHCHG' , 'Percent change in housing units: 2000 to 2010'] )
# add this to csv
for pair in abbreviations_explained:
    with open( '../data/tract-change/2010/tract-change-abbreviations.csv' , 'a' ) as csvfile:
        filewriter = csv.writer( csvfile, delimiter=',' )
        filewriter.writerow( pair )

# check csv
abbreviations_df = pd.read_csv( '../data/tract-change/2010/tract-change-abbreviations.csv' )

# %%
abbreviations_df
# Out:
#    Variable                               Variable Description
# 0     GEOID        Concatenated State-County-Census Tract Code
# 1      ST10                                    State FIPS Code
# 2     COU10                                   County FIPS Code
# 3   TRACT10                                  Census Tract Code
# 4   AREAL10                           Land area (square miles)
# 5   AREAW10                          Water area (square miles)
# 6     CSA09                     Combined Statistical Area Code
# 7    CBSA09            Core Based Statistical Area (CBSA) Code
# 8    CBSA_T                  Core Based Statistical Area Title
# 9    MDIV09                         Metropolitan Division Code
# 10      CSI  CBSA Status Indicator (1=Metropolitan statisti...
# 11    COFLG  Central/Outlying County Flag (C=Central county...
# 12    POP00                            Total population (2000)
# 13     HU00                         Total housing units (2000)
# ...
