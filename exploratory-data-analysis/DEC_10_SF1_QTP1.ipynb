# %%
import pandas as pd

# %%
# load metadata
metadata = pd.read_csv( '../data/2010/age-groups-and-sex-census-DEC_10_SF1_QTP1/DEC_10_SF1_QTP1_metadata.csv' )

# %%
metadata.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 289 entries, 0 to 288
# Data columns (total 2 columns):
# GEO.id    289 non-null object
# Id        289 non-null object
# dtypes: object(2)
# memory usage: 4.6+ KB

# %%
# load data
df = pd.read_csv( '../data/2010/age-groups-and-sex-census-DEC_10_SF1_QTP1/DEC_10_SF1_QTP1_with_ann.csv' , low_memory=False )

# %%
df.describe()
# Out:
#                 GEO.id GEO.id2 GEO.display-label SUBHD0101_S01 SUBHD0102_S01  \
# count            33121   33121             33121         33121         33121
# unique           33121   33121             33121         15428         11768
# top     8600000US16365   60070       ZCTA5 90712             0             0
# freq                 1       1                 1           144           152
#
#        SUBHD0103_S01 SUBHD0201_S01 SUBHD0202_S01 SUBHD0203_S01 HD03_S01  ...  \
# count          33121         33121         33121         33121    33121  ...
# unique         11957             3             3             3     1358  ...
# top                0         100.0         100.0         100.0    100.0  ...
# freq             157         32976         32968         32963      431  ...
#
#        SUBHD0202_S40 SUBHD0203_S40 HD03_S40 SUBHD0101_S41 SUBHD0102_S41  \
# count          33121         33121    33121         33121         33121
# ...

# %%
df[:6]
# Out:
#            GEO.id GEO.id2 GEO.display-label  \
# 0              Id     Id2         Geography
# 1  8600000US00601   00601       ZCTA5 00601
# 2  8600000US00602   00602       ZCTA5 00602
# 3  8600000US00603   00603       ZCTA5 00603
# 4  8600000US00606   00606       ZCTA5 00606
# 5  8600000US00610   00610       ZCTA5 00610
#
#                            SUBHD0101_S01                    SUBHD0102_S01  \
# 0  Number - Both sexes; Total population  Number - Male; Total population
# 1                                  18570                             9078
# 2                                  41520                            20396
# 3                                  54689                            26597
# 4                                   6615                             3268
# 5                                  29016                            14104
#
#                        SUBHD0103_S01                           SUBHD0201_S01  \
# ...

# %%
# df['GEO.display-label']
df['GEO.id']
# Out:
# 0                    Id
# 1        8600000US00601
# 2        8600000US00602
# 3        8600000US00603
# 4        8600000US00606
# 5        8600000US00610
# 6        8600000US00612
# 7        8600000US00616
# 8        8600000US00617
# 9        8600000US00622
# 10       8600000US00623
# 11       8600000US00624
# 12       8600000US00627
# 13       8600000US00631
# 14       8600000US00637
# 15       8600000US00638
# 16       8600000US00641
# 17       8600000US00646
# 18       8600000US00647
# 19       8600000US00650
# 20       8600000US00652
# 21       8600000US00653
# 22       8600000US00656
# 23       8600000US00659
# 24       8600000US00660
# 25       8600000US00662
# 26       8600000US00664
# 27       8600000US00667
# 28       8600000US00669
# 29       8600000US00670
#               ...
# 33091    8600000US99786
# 33092    8600000US99788
# 33093    8600000US99789
# 33094    8600000US99790
# 33095    8600000US99791
# 33096    8600000US99801
# 33097    8600000US99820
# ...

# %%
metadata
# Out:
#                 GEO.id                                                 Id
# 0              GEO.id2                                                Id2
# 1    GEO.display-label                                          Geography
# 2        SUBHD0101_S01              Number - Both sexes; Total population
# 3        SUBHD0102_S01                    Number - Male; Total population
# 4        SUBHD0103_S01                  Number - Female; Total population
# 5        SUBHD0201_S01             Percent - Both sexes; Total population
# 6        SUBHD0202_S01                   Percent - Male; Total population
# 7        SUBHD0203_S01                 Percent - Female; Total population
# 8             HD03_S01            Males per 100 females; Total population
# 9        SUBHD0101_S02  Number - Both sexes; Total population - Under ...
# 10       SUBHD0102_S02    Number - Male; Total population - Under 5 years
# 11       SUBHD0103_S02  Number - Female; Total population - Under 5 years
# ...
